# %%
import os
import pandas as pd

# %%
models = ['autoaugm_inceptionv2', 'autoaugm_resnet101', 'autoaugm_inception_resnet_v2_atrous_coco',
          'autoaugm_inception_resnet_v2_atrous_oidv4', 'autoaugm_nas']
data = []

for model in models:
    coco = pd.read_csv(model + '/eval_metrics/metrics_coco.csv', names=['metric', 'value'])
    pascal = pd.read_csv(model + '/eval_metrics/metrics_pascal.csv', names=['metric', 'value'])
    row = [coco.iloc[0]['value']] + pascal['value'].values.tolist()
    row = [round(value, 2) for value in row]
    data.append(row)

cols = ['map', 'map0_5', 'cabinet', 'chair', 'countertop', 'dishwasher',
         'outlet', 'oven', 'sofa', 'stool','stove', 'utensil']
metrics = pd.DataFrame(data, columns=cols, index=models)
metrics.to_csv('./metrics_aggregated.csv')
metrics
# Out:
#                                             map  map0_5  cabinet  chair  \
# autoaugm_inceptionv2                       0.62    0.84     0.83   0.87
# autoaugm_resnet101                         0.71    0.93     0.92   0.91
# autoaugm_inception_resnet_v2_atrous_coco   0.71    0.90     0.89   0.92
# autoaugm_inception_resnet_v2_atrous_oidv4  0.60    0.81     0.77   0.86
# autoaugm_nas                               0.43    0.64     0.34   0.78
#
#                                            countertop  dishwasher  outlet  \
# autoaugm_inceptionv2                             0.82        0.88    0.62
# autoaugm_resnet101                               0.91        0.93    0.82
# autoaugm_inception_resnet_v2_atrous_coco         0.89        0.92    0.78
# autoaugm_inception_resnet_v2_atrous_oidv4        0.78        0.85    0.63
# autoaugm_nas                                     0.59        0.64    0.49
#
#                                            oven  sofa  stool  stove  utensil
# autoaugm_inceptionv2                       0.95  0.67   0.94   0.92     0.87
# autoaugm_resnet101                         0.96  1.00   0.96   0.94     0.95
# autoaugm_inception_resnet_v2_atrous_coco   0.95  0.88   0.97   0.95     0.91
# autoaugm_inception_resnet_v2_atrous_oidv4  0.94  0.54   0.95   0.92     0.87
# autoaugm_nas                               0.85  0.33   0.81   0.84     0.74
