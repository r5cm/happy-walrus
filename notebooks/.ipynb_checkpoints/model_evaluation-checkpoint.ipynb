# %% [markdown]
# ## Kitchen training - test

# %%
import gdown
from sklearn.model_selection import train_test_split
import os
import shutil
import re
import pandas as pd
import time

OD_PATH = '/models/research/object_detection/'
MAIN_PATH = '/happy-walrus/models/version_3/'
IMG_PATH = MAIN_PATH + 'images/'
models = [('autoaugm_inceptionv2', '1gG7Dqc8JaMRFHP3AqNjolQvAmo3r2zU9'),
          ('autoaugm_resnet101', '1mOFlc9bKvSxnvw6mLycw0zCZtcTXYNka'),
          ('autoaugm_inception_resnet_v2_atrous_coco', '1iHtbPNe0RoC3xikPcl8fPYAPT24Dkedo'),
          ('autoaugm_inception_resnet_v2_atrous_oidv4', '1FcdeeS0NIV5rp7u74g2Q2kRMyya69gC6'),
          ('autoaugm_nas', "1ATOn9BSG5yuQLMWXxAG7yFEStCQ3Zqlk"),
          ('custaugm_resnet101', '1M47cRP4MM8bcN-M-PXgtErwEv-o_2dfR'),
          ('custaugm_inceptionv2', '1ASKFSkd7x4TvVtG1K6FvliK3hxOh_9-m'),
          ('custaugm_inception_resnet_v2_atrous_coco', "")]
model = 4
MODEL_NAME = models[model][0]
TRAIN_PATH = MAIN_PATH + 'training/' + MODEL_NAME
EVAL_PATH = MAIN_PATH + 'evaluation/' + MODEL_NAME
GRAPH_PATH = MAIN_PATH + 'inference_graph/' + MODEL_NAME

# %% [markdown]
# ### Export model

# %%
idx = models[model][1]
output = TRAIN_PATH + '.zip'
gdown.download(url="https://drive.google.com/uc?id=" + idx,
               output=output,
               quiet=False)
# !unzip -o -q {output} -d {MAIN_PATH}training
# !ls -l {TRAIN_PATH}
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ATOn9BSG5yuQLMWXxAG7yFEStCQ3Zqlk
# To: /happy-walrus/models/version_3/training/autoaugm_nas.zip
# 4.05GB [00:46, 86.9MB/s]
# total 6261892
# -rw-r--r-- 1 root root     224768 Nov 30 00:52 Tensorboard_custaugm_nas.png
# -rw-r--r-- 1 root root       3926 Nov 28 13:41 autoaugm_nas.config
# -rw-r--r-- 1 root root        595 Nov 29 11:33 checkpoint
# -rw-r--r-- 1 root root 2080472700 Nov 29 11:33 events.out.tfevents.1574948602.b40c62d10008
# -rw-r--r-- 1 root root   51739237 Nov 28 13:43 graph.pbtxt
# -rw-r--r-- 1 root root  829128576 Nov 29 10:53 model.ckpt-44114.data-00000-of-00001
# -rw-r--r-- 1 root root     121371 Nov 29 10:53 model.ckpt-44114.index
# -rw-r--r-- 1 root root   26686142 Nov 29 10:53 model.ckpt-44114.meta
# -rw-r--r-- 1 root root  829128576 Nov 29 11:03 model.ckpt-44461.data-00000-of-00001
# -rw-r--r-- 1 root root     121371 Nov 29 11:03 model.ckpt-44461.index
# -rw-r--r-- 1 root root   26686142 Nov 29 11:03 model.ckpt-44461.meta
# -rw-r--r-- 1 root root  829128576 Nov 29 11:13 model.ckpt-44808.data-00000-of-00001
# -rw-r--r-- 1 root root     121371 Nov 29 11:13 model.ckpt-44808.index
# -rw-r--r-- 1 root root   26686142 Nov 29 11:13 model.ckpt-44808.meta
# -rw-r--r-- 1 root root  829128576 Nov 29 11:23 model.ckpt-45155.data-00000-of-00001
# -rw-r--r-- 1 root root     121371 Nov 29 11:23 model.ckpt-45155.index
# -rw-r--r-- 1 root root   26686142 Nov 29 11:23 model.ckpt-45155.meta
# -rw-r--r-- 1 root root  829128576 Nov 29 11:33 model.ckpt-45503.data-00000-of-00001
# -rw-r--r-- 1 root root     121371 Nov 29 11:33 model.ckpt-45503.index
# -rw-r--r-- 1 root root   26686142 Nov 29 11:33 model.ckpt-45503.meta
# -rw-r--r-- 1 root root       3926 Nov 28 13:41 pipeline.config

# %%
checkpoint = 45503
# !python {OD_PATH}export_inference_graph.py \
    --input_type image_tensor \
    --pipeline_config_path {TRAIN_PATH}/{MODEL_NAME}.config \
    --trained_checkpoint_prefix {TRAIN_PATH}/model.ckpt-{checkpoint} \
    --output_directory {GRAPH_PATH}
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /models/research/object_detection/export_inference_graph.py:162: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /models/research/object_detection/export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W1130 21:13:04.893501 140533745248064 module_wrapper.py:139] From /models/research/object_detection/export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /models/research/object_detection/exporter.py:389: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# W1130 21:13:04.901104 140533745248064 module_wrapper.py:139] From /models/research/object_detection/exporter.py:389: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# WARNING:tensorflow:From /models/research/object_detection/exporter.py:121: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1130 21:13:04.901451 140533745248064 module_wrapper.py:139] From /models/research/object_detection/exporter.py:121: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /models/research/object_detection/core/preprocessor.py:2937: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# W1130 21:13:04.942485 140533745248064 module_wrapper.py:139] From /models/research/object_detection/core/preprocessor.py:2937: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:166: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W1130 21:13:04.978195 140533745248064 module_wrapper.py:139] From /models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:166: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# 2019-11-30 21:13:04.978990: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-11-30 21:13:04.986237: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100060000 Hz
# 2019-11-30 21:13:04.987058: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x6ddb2a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2019-11-30 21:13:04.987094: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2019-11-30 21:13:04.988685: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2019-11-30 21:13:04.988716: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2019-11-30 21:13:04.988742: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (5df86dfc3c25): /proc/driver/nvidia/version does not exist
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W1130 21:13:04.989722 140533745248064 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /models/research/object_detection/core/anchor_generator.py:171: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# W1130 21:13:13.917597 140533745248064 module_wrapper.py:139] From /models/research/object_detection/core/anchor_generator.py:171: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1130 21:13:13.926604 140533745248064 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:556: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# W1130 21:13:13.927072 140533745248064 module_wrapper.py:139] From /models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:556: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1130 21:13:13.947106 140533745248064 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /models/research/object_detection/predictors/convolutional_box_predictor.py:150: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W1130 21:13:13.947645 140533745248064 module_wrapper.py:139] From /models/research/object_detection/predictors/convolutional_box_predictor.py:150: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1130 21:13:13.947819 140533745248064 convolutional_box_predictor.py:151] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /models/research/object_detection/core/box_list_ops.py:141: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1130 21:13:14.020311 140533745248064 deprecation.py:323] From /models/research/object_detection/core/box_list_ops.py:141: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /models/research/object_detection/utils/spatial_transform_ops.py:419: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# W1130 21:13:14.732580 140533745248064 deprecation.py:506] From /models/research/object_detection/utils/spatial_transform_ops.py:419: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From /models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:189: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W1130 21:13:14.755841 140533745248064 module_wrapper.py:139] From /models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:189: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# W1130 21:13:19.451929 140533745248064 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1130 21:13:19.459634 140533745248064 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1130 21:13:19.489780 140533745248064 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/dispatch.py:180: batch_gather (from tensorflow.python.ops.array_ops) is deprecated and will be removed after 2017-10-25.
# Instructions for updating:
# `tf.batch_gather` is deprecated, please use `tf.gather` with `batch_dims=-1` instead.
# W1130 21:13:20.648039 140533745248064 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/dispatch.py:180: batch_gather (from tensorflow.python.ops.array_ops) is deprecated and will be removed after 2017-10-25.
# Instructions for updating:
# `tf.batch_gather` is deprecated, please use `tf.gather` with `batch_dims=-1` instead.
# WARNING:tensorflow:From /models/research/object_detection/exporter.py:268: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# W1130 21:13:22.564206 140533745248064 module_wrapper.py:139] From /models/research/object_detection/exporter.py:268: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /models/research/object_detection/exporter.py:370: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# W1130 21:13:22.564582 140533745248064 deprecation.py:323] From /models/research/object_detection/exporter.py:370: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# WARNING:tensorflow:From /models/research/object_detection/exporter.py:402: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1130 21:13:22.568820 140533745248064 module_wrapper.py:139] From /models/research/object_detection/exporter.py:402: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /models/research/object_detection/exporter.py:526: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# W1130 21:13:22.569039 140533745248064 deprecation.py:323] From /models/research/object_detection/exporter.py:526: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# W1130 21:13:22.570901 140533745248064 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# 891 ops no flops stats due to incomplete shapes.
# Parsing Inputs...
# Incomplete shape.
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              0
# -min_occurrence             0
# -step                       -1
# -order_by                   name
# -account_type_regexes       _trainable_variables
# -start_name_regexes         .*
# -trim_name_regexes          .*BatchNorm.*
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     params
# -output                     stdout:
#
# ==================Model Analysis Report======================
# Incomplete shape.
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# param: Number of parameters (in the Variable).
#
# Profile:
# node name | # parameters
# _TFProfRoot (--/103.54m params)
#   Conv (--/18.58m params)
#     Conv/biases (512, 512/512 params)
#     Conv/weights (3x3x4032x512, 18.58m/18.58m params)
#   FirstStageBoxPredictor (--/36.94k params)
#     FirstStageBoxPredictor/BoxEncodingPredictor (--/24.62k params)
#       FirstStageBoxPredictor/BoxEncodingPredictor/biases (48, 48/48 params)
#       FirstStageBoxPredictor/BoxEncodingPredictor/weights (1x1x512x48, 24.58k/24.58k params)
#     FirstStageBoxPredictor/ClassPredictor (--/12.31k params)
#       FirstStageBoxPredictor/ClassPredictor/biases (24, 24/24 params)
#       FirstStageBoxPredictor/ClassPredictor/weights (1x1x512x24, 12.29k/12.29k params)
#   FirstStageFeatureExtractor (--/20.10m params)
#     FirstStageFeatureExtractor/cell_0 (--/396.82k params)
#       FirstStageFeatureExtractor/cell_0/1x1 (--/56.45k params)
#         FirstStageFeatureExtractor/cell_0/1x1/weights (1x1x336x168, 56.45k/56.45k params)
#       FirstStageFeatureExtractor/cell_0/beginning_bn (--/336 params)
#         FirstStageFeatureExtractor/cell_0/beginning_bn/beta (168, 168/168 params)
#         FirstStageFeatureExtractor/cell_0/beginning_bn/gamma (168, 168/168 params)
#       FirstStageFeatureExtractor/cell_0/comb_iter_0 (--/125.66k params)
#         FirstStageFeatureExtractor/cell_0/comb_iter_0/left (--/65.52k params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_0/left/bn_sep_5x5_1 (--/336 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/left/bn_sep_5x5_1/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/left/bn_sep_5x5_1/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_0/left/bn_sep_5x5_2 (--/336 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/left/bn_sep_5x5_2/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/left/bn_sep_5x5_2/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_0/left/separable_5x5_1 (--/32.42k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/left/separable_5x5_1/depthwise_weights (5x5x168x1, 4.20k/4.20k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/left/separable_5x5_1/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_0/left/separable_5x5_2 (--/32.42k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/left/separable_5x5_2/depthwise_weights (5x5x168x1, 4.20k/4.20k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/left/separable_5x5_2/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#         FirstStageFeatureExtractor/cell_0/comb_iter_0/right (--/60.14k params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_0/right/bn_sep_3x3_1 (--/336 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/right/bn_sep_3x3_1/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/right/bn_sep_3x3_1/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_0/right/bn_sep_3x3_2 (--/336 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/right/bn_sep_3x3_2/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/right/bn_sep_3x3_2/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_0/right/separable_3x3_1 (--/29.74k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/right/separable_3x3_1/depthwise_weights (3x3x168x1, 1.51k/1.51k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/right/separable_3x3_1/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_0/right/separable_3x3_2 (--/29.74k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/right/separable_3x3_2/depthwise_weights (3x3x168x1, 1.51k/1.51k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_0/right/separable_3x3_2/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#       FirstStageFeatureExtractor/cell_0/comb_iter_1 (--/125.66k params)
#         FirstStageFeatureExtractor/cell_0/comb_iter_1/left (--/65.52k params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_1/left/bn_sep_5x5_1 (--/336 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/left/bn_sep_5x5_1/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/left/bn_sep_5x5_1/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_1/left/bn_sep_5x5_2 (--/336 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/left/bn_sep_5x5_2/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/left/bn_sep_5x5_2/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_1/left/separable_5x5_1 (--/32.42k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/left/separable_5x5_1/depthwise_weights (5x5x168x1, 4.20k/4.20k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/left/separable_5x5_1/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_1/left/separable_5x5_2 (--/32.42k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/left/separable_5x5_2/depthwise_weights (5x5x168x1, 4.20k/4.20k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/left/separable_5x5_2/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#         FirstStageFeatureExtractor/cell_0/comb_iter_1/right (--/60.14k params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_1/right/bn_sep_3x3_1 (--/336 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/right/bn_sep_3x3_1/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/right/bn_sep_3x3_1/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_1/right/bn_sep_3x3_2 (--/336 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/right/bn_sep_3x3_2/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/right/bn_sep_3x3_2/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_1/right/separable_3x3_1 (--/29.74k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/right/separable_3x3_1/depthwise_weights (3x3x168x1, 1.51k/1.51k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/right/separable_3x3_1/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_1/right/separable_3x3_2 (--/29.74k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/right/separable_3x3_2/depthwise_weights (3x3x168x1, 1.51k/1.51k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_1/right/separable_3x3_2/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#       FirstStageFeatureExtractor/cell_0/comb_iter_4 (--/60.14k params)
#         FirstStageFeatureExtractor/cell_0/comb_iter_4/left (--/60.14k params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_4/left/bn_sep_3x3_1 (--/336 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_4/left/bn_sep_3x3_1/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_4/left/bn_sep_3x3_1/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_4/left/bn_sep_3x3_2 (--/336 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_4/left/bn_sep_3x3_2/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_4/left/bn_sep_3x3_2/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_4/left/separable_3x3_1 (--/29.74k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_4/left/separable_3x3_1/depthwise_weights (3x3x168x1, 1.51k/1.51k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_4/left/separable_3x3_1/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#           FirstStageFeatureExtractor/cell_0/comb_iter_4/left/separable_3x3_2 (--/29.74k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_4/left/separable_3x3_2/depthwise_weights (3x3x168x1, 1.51k/1.51k params)
#             FirstStageFeatureExtractor/cell_0/comb_iter_4/left/separable_3x3_2/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#       FirstStageFeatureExtractor/cell_0/final_path_bn (--/336 params)
#         FirstStageFeatureExtractor/cell_0/final_path_bn/beta (168, 168/168 params)
#         FirstStageFeatureExtractor/cell_0/final_path_bn/gamma (168, 168/168 params)
#       FirstStageFeatureExtractor/cell_0/path1_conv (--/14.11k params)
#         FirstStageFeatureExtractor/cell_0/path1_conv/weights (1x1x168x84, 14.11k/14.11k params)
#       FirstStageFeatureExtractor/cell_0/path2_conv (--/14.11k params)
#         FirstStageFeatureExtractor/cell_0/path2_conv/weights (1x1x168x84, 14.11k/14.11k params)
#     FirstStageFeatureExtractor/cell_1 (--/537.94k params)
#       FirstStageFeatureExtractor/cell_1/1x1 (--/169.34k params)
#         FirstStageFeatureExtractor/cell_1/1x1/weights (1x1x1008x168, 169.34k/169.34k params)
#       FirstStageFeatureExtractor/cell_1/beginning_bn (--/336 params)
#         FirstStageFeatureExtractor/cell_1/beginning_bn/beta (168, 168/168 params)
#         FirstStageFeatureExtractor/cell_1/beginning_bn/gamma (168, 168/168 params)
#       FirstStageFeatureExtractor/cell_1/comb_iter_0 (--/125.66k params)
#         FirstStageFeatureExtractor/cell_1/comb_iter_0/left (--/65.52k params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_0/left/bn_sep_5x5_1 (--/336 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/left/bn_sep_5x5_1/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/left/bn_sep_5x5_1/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_0/left/bn_sep_5x5_2 (--/336 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/left/bn_sep_5x5_2/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/left/bn_sep_5x5_2/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_0/left/separable_5x5_1 (--/32.42k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/left/separable_5x5_1/depthwise_weights (5x5x168x1, 4.20k/4.20k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/left/separable_5x5_1/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_0/left/separable_5x5_2 (--/32.42k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/left/separable_5x5_2/depthwise_weights (5x5x168x1, 4.20k/4.20k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/left/separable_5x5_2/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#         FirstStageFeatureExtractor/cell_1/comb_iter_0/right (--/60.14k params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_0/right/bn_sep_3x3_1 (--/336 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/right/bn_sep_3x3_1/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/right/bn_sep_3x3_1/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_0/right/bn_sep_3x3_2 (--/336 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/right/bn_sep_3x3_2/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/right/bn_sep_3x3_2/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_0/right/separable_3x3_1 (--/29.74k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/right/separable_3x3_1/depthwise_weights (3x3x168x1, 1.51k/1.51k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/right/separable_3x3_1/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_0/right/separable_3x3_2 (--/29.74k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/right/separable_3x3_2/depthwise_weights (3x3x168x1, 1.51k/1.51k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_0/right/separable_3x3_2/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#       FirstStageFeatureExtractor/cell_1/comb_iter_1 (--/125.66k params)
#         FirstStageFeatureExtractor/cell_1/comb_iter_1/left (--/65.52k params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_1/left/bn_sep_5x5_1 (--/336 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/left/bn_sep_5x5_1/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/left/bn_sep_5x5_1/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_1/left/bn_sep_5x5_2 (--/336 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/left/bn_sep_5x5_2/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/left/bn_sep_5x5_2/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_1/left/separable_5x5_1 (--/32.42k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/left/separable_5x5_1/depthwise_weights (5x5x168x1, 4.20k/4.20k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/left/separable_5x5_1/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_1/left/separable_5x5_2 (--/32.42k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/left/separable_5x5_2/depthwise_weights (5x5x168x1, 4.20k/4.20k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/left/separable_5x5_2/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#         FirstStageFeatureExtractor/cell_1/comb_iter_1/right (--/60.14k params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_1/right/bn_sep_3x3_1 (--/336 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/right/bn_sep_3x3_1/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/right/bn_sep_3x3_1/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_1/right/bn_sep_3x3_2 (--/336 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/right/bn_sep_3x3_2/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/right/bn_sep_3x3_2/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_1/right/separable_3x3_1 (--/29.74k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/right/separable_3x3_1/depthwise_weights (3x3x168x1, 1.51k/1.51k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/right/separable_3x3_1/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_1/right/separable_3x3_2 (--/29.74k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/right/separable_3x3_2/depthwise_weights (3x3x168x1, 1.51k/1.51k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_1/right/separable_3x3_2/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#       FirstStageFeatureExtractor/cell_1/comb_iter_4 (--/60.14k params)
#         FirstStageFeatureExtractor/cell_1/comb_iter_4/left (--/60.14k params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_4/left/bn_sep_3x3_1 (--/336 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_4/left/bn_sep_3x3_1/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_4/left/bn_sep_3x3_1/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_4/left/bn_sep_3x3_2 (--/336 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_4/left/bn_sep_3x3_2/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_4/left/bn_sep_3x3_2/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_4/left/separable_3x3_1 (--/29.74k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_4/left/separable_3x3_1/depthwise_weights (3x3x168x1, 1.51k/1.51k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_4/left/separable_3x3_1/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#           FirstStageFeatureExtractor/cell_1/comb_iter_4/left/separable_3x3_2 (--/29.74k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_4/left/separable_3x3_2/depthwise_weights (3x3x168x1, 1.51k/1.51k params)
#             FirstStageFeatureExtractor/cell_1/comb_iter_4/left/separable_3x3_2/pointwise_weights (1x1x168x168, 28.22k/28.22k params)
#       FirstStageFeatureExtractor/cell_1/prev_1x1 (--/56.45k params)
#         FirstStageFeatureExtractor/cell_1/prev_1x1/weights (1x1x336x168, 56.45k/56.45k params)
#       FirstStageFeatureExtractor/cell_1/prev_bn (--/336 params)
#         FirstStageFeatureExtractor/cell_1/prev_bn/beta (168, 168/168 params)
#         FirstStageFeatureExtractor/cell_1/prev_bn/gamma (168, 168/168 params)
#     FirstStageFeatureExtractor/cell_10 (--/2.54m params)
#       FirstStageFeatureExtractor/cell_10/1x1 (--/677.38k params)
#         FirstStageFeatureExtractor/cell_10/1x1/weights (1x1x2016x336, 677.38k/677.38k params)
#       FirstStageFeatureExtractor/cell_10/beginning_bn (--/672 params)
#         FirstStageFeatureExtractor/cell_10/beginning_bn/beta (336, 336/336 params)
#         FirstStageFeatureExtractor/cell_10/beginning_bn/gamma (336, 336/336 params)
#       FirstStageFeatureExtractor/cell_10/comb_iter_0 (--/477.12k params)
#         FirstStageFeatureExtractor/cell_10/comb_iter_0/left (--/243.94k params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_0/left/bn_sep_5x5_1 (--/672 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/left/bn_sep_5x5_1/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/left/bn_sep_5x5_1/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_0/left/bn_sep_5x5_2 (--/672 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/left/bn_sep_5x5_2/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/left/bn_sep_5x5_2/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_0/left/separable_5x5_1 (--/121.30k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/left/separable_5x5_1/depthwise_weights (5x5x336x1, 8.40k/8.40k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/left/separable_5x5_1/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_0/left/separable_5x5_2 (--/121.30k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/left/separable_5x5_2/depthwise_weights (5x5x336x1, 8.40k/8.40k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/left/separable_5x5_2/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#         FirstStageFeatureExtractor/cell_10/comb_iter_0/right (--/233.18k params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_0/right/bn_sep_3x3_1 (--/672 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/right/bn_sep_3x3_1/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/right/bn_sep_3x3_1/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_0/right/bn_sep_3x3_2 (--/672 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/right/bn_sep_3x3_2/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/right/bn_sep_3x3_2/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_0/right/separable_3x3_1 (--/115.92k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/right/separable_3x3_1/depthwise_weights (3x3x336x1, 3.02k/3.02k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/right/separable_3x3_1/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_0/right/separable_3x3_2 (--/115.92k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/right/separable_3x3_2/depthwise_weights (3x3x336x1, 3.02k/3.02k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_0/right/separable_3x3_2/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#       FirstStageFeatureExtractor/cell_10/comb_iter_1 (--/477.12k params)
#         FirstStageFeatureExtractor/cell_10/comb_iter_1/left (--/243.94k params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_1/left/bn_sep_5x5_1 (--/672 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/left/bn_sep_5x5_1/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/left/bn_sep_5x5_1/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_1/left/bn_sep_5x5_2 (--/672 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/left/bn_sep_5x5_2/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/left/bn_sep_5x5_2/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_1/left/separable_5x5_1 (--/121.30k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/left/separable_5x5_1/depthwise_weights (5x5x336x1, 8.40k/8.40k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/left/separable_5x5_1/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_1/left/separable_5x5_2 (--/121.30k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/left/separable_5x5_2/depthwise_weights (5x5x336x1, 8.40k/8.40k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/left/separable_5x5_2/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#         FirstStageFeatureExtractor/cell_10/comb_iter_1/right (--/233.18k params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_1/right/bn_sep_3x3_1 (--/672 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/right/bn_sep_3x3_1/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/right/bn_sep_3x3_1/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_1/right/bn_sep_3x3_2 (--/672 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/right/bn_sep_3x3_2/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/right/bn_sep_3x3_2/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_1/right/separable_3x3_1 (--/115.92k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/right/separable_3x3_1/depthwise_weights (3x3x336x1, 3.02k/3.02k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/right/separable_3x3_1/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_1/right/separable_3x3_2 (--/115.92k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/right/separable_3x3_2/depthwise_weights (3x3x336x1, 3.02k/3.02k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_1/right/separable_3x3_2/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#       FirstStageFeatureExtractor/cell_10/comb_iter_4 (--/233.18k params)
#         FirstStageFeatureExtractor/cell_10/comb_iter_4/left (--/233.18k params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_4/left/bn_sep_3x3_1 (--/672 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_4/left/bn_sep_3x3_1/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_4/left/bn_sep_3x3_1/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_4/left/bn_sep_3x3_2 (--/672 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_4/left/bn_sep_3x3_2/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_4/left/bn_sep_3x3_2/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_4/left/separable_3x3_1 (--/115.92k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_4/left/separable_3x3_1/depthwise_weights (3x3x336x1, 3.02k/3.02k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_4/left/separable_3x3_1/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#           FirstStageFeatureExtractor/cell_10/comb_iter_4/left/separable_3x3_2 (--/115.92k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_4/left/separable_3x3_2/depthwise_weights (3x3x336x1, 3.02k/3.02k params)
#             FirstStageFeatureExtractor/cell_10/comb_iter_4/left/separable_3x3_2/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#       FirstStageFeatureExtractor/cell_10/prev_1x1 (--/677.38k params)
#         FirstStageFeatureExtractor/cell_10/prev_1x1/weights (1x1x2016x336, 677.38k/677.38k params)
#       FirstStageFeatureExtractor/cell_10/prev_bn (--/672 params)
#         FirstStageFeatureExtractor/cell_10/prev_bn/beta (336, 336/336 params)
#         FirstStageFeatureExtractor/cell_10/prev_bn/gamma (336, 336/336 params)
#     FirstStageFeatureExtractor/cell_11 (--/2.54m params)
#       FirstStageFeatureExtractor/cell_11/1x1 (--/677.38k params)
#         FirstStageFeatureExtractor/cell_11/1x1/weights (1x1x2016x336, 677.38k/677.38k params)
#       FirstStageFeatureExtractor/cell_11/beginning_bn (--/672 params)
#         FirstStageFeatureExtractor/cell_11/beginning_bn/beta (336, 336/336 params)
#         FirstStageFeatureExtractor/cell_11/beginning_bn/gamma (336, 336/336 params)
#       FirstStageFeatureExtractor/cell_11/comb_iter_0 (--/477.12k params)
#         FirstStageFeatureExtractor/cell_11/comb_iter_0/left (--/243.94k params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_0/left/bn_sep_5x5_1 (--/672 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/left/bn_sep_5x5_1/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/left/bn_sep_5x5_1/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_0/left/bn_sep_5x5_2 (--/672 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/left/bn_sep_5x5_2/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/left/bn_sep_5x5_2/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_0/left/separable_5x5_1 (--/121.30k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/left/separable_5x5_1/depthwise_weights (5x5x336x1, 8.40k/8.40k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/left/separable_5x5_1/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_0/left/separable_5x5_2 (--/121.30k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/left/separable_5x5_2/depthwise_weights (5x5x336x1, 8.40k/8.40k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/left/separable_5x5_2/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#         FirstStageFeatureExtractor/cell_11/comb_iter_0/right (--/233.18k params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_0/right/bn_sep_3x3_1 (--/672 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/right/bn_sep_3x3_1/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/right/bn_sep_3x3_1/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_0/right/bn_sep_3x3_2 (--/672 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/right/bn_sep_3x3_2/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/right/bn_sep_3x3_2/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_0/right/separable_3x3_1 (--/115.92k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/right/separable_3x3_1/depthwise_weights (3x3x336x1, 3.02k/3.02k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/right/separable_3x3_1/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_0/right/separable_3x3_2 (--/115.92k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/right/separable_3x3_2/depthwise_weights (3x3x336x1, 3.02k/3.02k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_0/right/separable_3x3_2/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#       FirstStageFeatureExtractor/cell_11/comb_iter_1 (--/477.12k params)
#         FirstStageFeatureExtractor/cell_11/comb_iter_1/left (--/243.94k params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_1/left/bn_sep_5x5_1 (--/672 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/left/bn_sep_5x5_1/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/left/bn_sep_5x5_1/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_1/left/bn_sep_5x5_2 (--/672 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/left/bn_sep_5x5_2/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/left/bn_sep_5x5_2/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_1/left/separable_5x5_1 (--/121.30k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/left/separable_5x5_1/depthwise_weights (5x5x336x1, 8.40k/8.40k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/left/separable_5x5_1/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_1/left/separable_5x5_2 (--/121.30k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/left/separable_5x5_2/depthwise_weights (5x5x336x1, 8.40k/8.40k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/left/separable_5x5_2/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#         FirstStageFeatureExtractor/cell_11/comb_iter_1/right (--/233.18k params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_1/right/bn_sep_3x3_1 (--/672 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/right/bn_sep_3x3_1/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/right/bn_sep_3x3_1/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_1/right/bn_sep_3x3_2 (--/672 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/right/bn_sep_3x3_2/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/right/bn_sep_3x3_2/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_1/right/separable_3x3_1 (--/115.92k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/right/separable_3x3_1/depthwise_weights (3x3x336x1, 3.02k/3.02k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/right/separable_3x3_1/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_1/right/separable_3x3_2 (--/115.92k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/right/separable_3x3_2/depthwise_weights (3x3x336x1, 3.02k/3.02k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_1/right/separable_3x3_2/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#       FirstStageFeatureExtractor/cell_11/comb_iter_4 (--/233.18k params)
#         FirstStageFeatureExtractor/cell_11/comb_iter_4/left (--/233.18k params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_4/left/bn_sep_3x3_1 (--/672 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_4/left/bn_sep_3x3_1/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_4/left/bn_sep_3x3_1/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_4/left/bn_sep_3x3_2 (--/672 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_4/left/bn_sep_3x3_2/beta (336, 336/336 params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_4/left/bn_sep_3x3_2/gamma (336, 336/336 params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_4/left/separable_3x3_1 (--/115.92k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_4/left/separable_3x3_1/depthwise_weights (3x3x336x1, 3.02k/3.02k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_4/left/separable_3x3_1/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#           FirstStageFeatureExtractor/cell_11/comb_iter_4/left/separable_3x3_2 (--/115.92k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_4/left/separable_3x3_2/depthwise_weights (3x3x336x1, 3.02k/3.02k params)
#             FirstStageFeatureExtractor/cell_11/comb_iter_4/left/separable_3x3_2/pointwise_weights (1x1x336x336, 112.90k/112.90k params)
#       FirstStageFeatureExtractor/cell_11/prev_1x1 (--/677.38k params)
#         FirstStageFeatureExtractor/cell_11/prev_1x1/weights (1x1x2016x336, 677.38k/677.38k params)
#       FirstStageFeatureExtractor/cell_11/prev_bn (--/672 params)
#         FirstStageFeatureExtractor/cell_11/prev_bn/beta (336, 336/336 params)
#         FirstStageFeatureExtractor/cell_11/prev_bn/gamma (336, 336/336 params)
#     FirstStageFeatureExtractor/cell_2 (--/650.83k params)
#       FirstStageFeatureExtractor/cell_2/1x1 (--/169.34k params)
#         FirstStageFeatureExtractor/cell_2/1x1/weights (1x1x1008x168, 169.34k/169.34k params)
#       FirstStageFeatureExtractor/cell_2/beginning_bn (--/336 params)
#         FirstStageFeatureExtractor/cell_2/beginning_bn/beta (168, 168/168 params)
#         FirstStageFeatureExtractor/cell_2/beginning_bn/gamma (168, 168/168 params)
#       FirstStageFeatureExtractor/cell_2/comb_iter_0 (--/125.66k params)
#         FirstStageFeatureExtractor/cell_2/comb_iter_0/left (--/65.52k params)
#           FirstStageFeatureExtractor/cell_2/comb_iter_0/left/bn_sep_5x5_1 (--/336 params)
#             FirstStageFeatureExtractor/cell_2/comb_iter_0/left/bn_sep_5x5_1/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_2/comb_iter_0/left/bn_sep_5x5_1/gamma (168, 168/168 params)
#           FirstStageFeatureExtractor/cell_2/comb_iter_0/left/bn_sep_5x5_2 (--/336 params)
#             FirstStageFeatureExtractor/cell_2/comb_iter_0/left/bn_sep_5x5_2/beta (168, 168/168 params)
#             FirstStageFeatureExtractor/cell_2/comb_iter_0/left/bn_sep_5x5_2/gamma (168, 168/168 params)
# ...
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_3 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_2 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_19 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_18 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_17 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_16 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_3 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_10 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_11 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_12 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_13 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_14 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_15 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_16 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_17 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_2 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_1 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_4 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_5 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_6 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_7 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_8 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_9 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/ones/Less (1/1 flops)
#   GridAnchorGenerator/assert_equal_1/Equal (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_1 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/Less_1 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Greater (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_1 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/SortByField/Equal (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/SortByField_1/Equal (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_1 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater (1/1 flops)
#   GridAnchorGenerator/mul_7 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_2 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_3 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_4 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_5 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_6 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_7 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_8 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_3 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_4 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_5 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_6 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_7 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_8 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_9 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/SortByField/Equal (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/SortByField_1/Equal (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_2 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_10 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_11 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_12 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_13 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_14 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/Less (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_16 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/Less_1 (1/1 flops)
#   GridAnchorGenerator/mul_8 (1/1 flops)
#   GridAnchorGenerator/zeros/Less (1/1 flops)
#   Preprocessor/map/while/Less (1/1 flops)
#   Preprocessor/map/while/Less_1 (1/1 flops)
#   SecondStageDetectionFeaturesExtract/mul (1/1 flops)
#   SecondStagePostprocessor/BatchGather/mul (1/1 flops)
#   SecondStagePostprocessor/BatchGather/mul_2 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/Less (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_17 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/sub (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/sub_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/truediv (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/truediv_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Greater (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_10 (1/1 flops)
#
# ======================End of Report==========================
# WARNING:tensorflow:From /models/research/object_detection/exporter.py:419: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W1130 21:13:28.964625 140533745248064 module_wrapper.py:139] From /models/research/object_detection/exporter.py:419: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /models/research/object_detection/exporter.py:332: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W1130 21:13:33.409921 140533745248064 module_wrapper.py:139] From /models/research/object_detection/exporter.py:332: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# INFO:tensorflow:Restoring parameters from /happy-walrus/models/version_3/training/autoaugm_nas/model.ckpt-45503
# I1130 21:13:33.412935 140533745248064 saver.py:1284] Restoring parameters from /happy-walrus/models/version_3/training/autoaugm_nas/model.ckpt-45503
# 2019-11-30 21:13:36.488143: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 74317824 exceeds 10% of system memory.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# W1130 21:13:41.021163 140533745248064 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /happy-walrus/models/version_3/training/autoaugm_nas/model.ckpt-45503
# I1130 21:13:44.087477 140533745248064 saver.py:1284] Restoring parameters from /happy-walrus/models/version_3/training/autoaugm_nas/model.ckpt-45503
# 2019-11-30 21:13:48.533505: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 74317824 exceeds 10% of system memory.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/tools/freeze_graph.py:233: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W1130 21:13:48.922574 140533745248064 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/tools/freeze_graph.py:233: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# W1130 21:13:48.922897 140533745248064 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 1554 variables.
# I1130 21:13:51.591303 140533745248064 graph_util_impl.py:334] Froze 1554 variables.
# INFO:tensorflow:Converted 1554 variables to const ops.
# I1130 21:13:52.497865 140533745248064 graph_util_impl.py:394] Converted 1554 variables to const ops.
# WARNING:tensorflow:From /models/research/object_detection/exporter.py:296: The name tf.saved_model.builder.SavedModelBuilder is deprecated. Please use tf.compat.v1.saved_model.builder.SavedModelBuilder instead.
#
# W1130 21:13:56.795824 140533745248064 module_wrapper.py:139] From /models/research/object_detection/exporter.py:296: The name tf.saved_model.builder.SavedModelBuilder is deprecated. Please use tf.compat.v1.saved_model.builder.SavedModelBuilder instead.
#
# WARNING:tensorflow:From /models/research/object_detection/exporter.py:299: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W1130 21:13:56.796389 140533745248064 deprecation.py:323] From /models/research/object_detection/exporter.py:299: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# WARNING:tensorflow:From /models/research/object_detection/exporter.py:305: The name tf.saved_model.signature_def_utils.build_signature_def is deprecated. Please use tf.compat.v1.saved_model.signature_def_utils.build_signature_def instead.
#
# W1130 21:13:56.796988 140533745248064 module_wrapper.py:139] From /models/research/object_detection/exporter.py:305: The name tf.saved_model.signature_def_utils.build_signature_def is deprecated. Please use tf.compat.v1.saved_model.signature_def_utils.build_signature_def instead.
#
# WARNING:tensorflow:From /models/research/object_detection/exporter.py:308: The name tf.saved_model.signature_constants.PREDICT_METHOD_NAME is deprecated. Please use tf.saved_model.PREDICT_METHOD_NAME instead.
#
# W1130 21:13:56.797205 140533745248064 module_wrapper.py:139] From /models/research/object_detection/exporter.py:308: The name tf.saved_model.signature_constants.PREDICT_METHOD_NAME is deprecated. Please use tf.saved_model.PREDICT_METHOD_NAME instead.
#
# WARNING:tensorflow:From /models/research/object_detection/exporter.py:313: The name tf.saved_model.tag_constants.SERVING is deprecated. Please use tf.saved_model.SERVING instead.
#
# W1130 21:13:56.797506 140533745248064 module_wrapper.py:139] From /models/research/object_detection/exporter.py:313: The name tf.saved_model.tag_constants.SERVING is deprecated. Please use tf.saved_model.SERVING instead.
#
# WARNING:tensorflow:From /models/research/object_detection/exporter.py:315: The name tf.saved_model.signature_constants.DEFAULT_SERVING_SIGNATURE_DEF_KEY is deprecated. Please use tf.saved_model.DEFAULT_SERVING_SIGNATURE_DEF_KEY instead.
#
# W1130 21:13:56.797690 140533745248064 module_wrapper.py:139] From /models/research/object_detection/exporter.py:315: The name tf.saved_model.signature_constants.DEFAULT_SERVING_SIGNATURE_DEF_KEY is deprecated. Please use tf.saved_model.DEFAULT_SERVING_SIGNATURE_DEF_KEY instead.
#
# INFO:tensorflow:No assets to save.
# I1130 21:13:56.798042 140533745248064 builder_impl.py:640] No assets to save.
# INFO:tensorflow:No assets to write.
# I1130 21:13:56.798171 140533745248064 builder_impl.py:460] No assets to write.
# INFO:tensorflow:SavedModel written to: /happy-walrus/models/version_3/inference_graph/autoaugm_nas/saved_model/saved_model.pb
# I1130 21:13:59.679095 140533745248064 builder_impl.py:425] SavedModel written to: /happy-walrus/models/version_3/inference_graph/autoaugm_nas/saved_model/saved_model.pb
# WARNING:tensorflow:From /models/research/object_detection/utils/config_util.py:188: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# W1130 21:13:59.798440 140533745248064 module_wrapper.py:139] From /models/research/object_detection/utils/config_util.py:188: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# INFO:tensorflow:Writing pipeline config file to /happy-walrus/models/version_3/inference_graph/autoaugm_nas/pipeline.config
# I1130 21:13:59.798734 140533745248064 config_util.py:190] Writing pipeline config file to /happy-walrus/models/version_3/inference_graph/autoaugm_nas/pipeline.config

# %% [markdown]
# Download model and store it in Google Drive for use in next section (not necessary if model is already in disk).

# %%
zip_name = GRAPH_PATH + MODEL_NAME[:-1] + '.zip'
# !zip -qr {zip_name} {GRAPH_PATH}

# %% [markdown]
# # 2. Evaluation

# %% [markdown]
# ### Download model (only if model is not on disk)

# %%
# Download model
model_id = "1JVFhXqaayxWOIhuQdzmjIMBAHrAhLcEQ"
model_name = "inference_graph.zip"
gdown.download(url="https://drive.google.com/uc?id=" + model_id,
               output=MAIN_PATH + model_name,
               quiet=False)

# Unzip model
# !unzip -q {MAIN_PATH}{model_name} -d {MAIN_PATH}
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1JVFhXqaayxWOIhuQdzmjIMBAHrAhLcEQ
# To: /happy-walrus/models/version_2/inference_graph.zip
# 144MB [00:01, 74.9MB/s]

# %% [markdown]
# ### Bounding boxes

# %% [markdown]
# To `Object_detection_image.py`:
# - Update `MODEL_NAME`

# %%
MODEL_NAME
# Out:
# 'autoaugm_nas'

# %%
# !mkdir {EVAL_PATH}
# !mkdir {EVAL_PATH}/bboxes
# !cat {MAIN_PATH}Object_detection_image.py
# Out:
# ######## Image Object Detection Using Tensorflow-trained Classifier #########
# #
# # Author: Evan Juras
# # Date: 1/15/18
# # Description:
# # This program uses a TensorFlow-trained neural network to perform object detection.
# # It loads the classifier and uses it to perform object detection on an image.
# # It draws boxes, scores, and labels around the objects of interest in the image.
#
# ## Some of the code is copied from Google's example at
# ## https://github.com/tensorflow/models/blob/master/research/object_detection/object_detection_tutorial.ipynb
#
# ## and some is copied from Dat Tran's example at
# ## https://github.com/datitran/object_detector_app/blob/master/object_detection_app.py
#
# ## but I changed it to make it more understandable to me.
#
# # Import packages
# import os
# import cv2
# import numpy as np
# import tensorflow as tf
# import sys
# import re
#
# # This is needed since the notebook is stored in the object_detection folder.
# sys.path.append("..")
#
# # Import utilites
# from object_detection.utils import label_map_util
# from object_detection.utils import visualization_utils as vis_util
#
# # Name of the directory containing the object detection module we're using
# MODEL_NAME = 'autoaugm_nas'
# MODEL_PATH = 'inference_graph/' + MODEL_NAME
#
# # Grab path to current working directory
# CWD_PATH = os.getcwd()
#
# # Path to frozen detection graph .pb file, which contains the model that is used
# # for object detection.
# PATH_TO_CKPT = os.path.join(CWD_PATH,MODEL_PATH,'frozen_inference_graph.pb')
#
# # Path to label map file
# PATH_TO_LABELS = os.path.join(CWD_PATH,'training','labelmap.pbtxt')
#
# # Path to image
# #PATH_TO_IMAGE = os.path.join(CWD_PATH,IMAGE_NAME)
#
# # Number of classes the object detector can identify
# NUM_CLASSES = 10
#
# # Load the label map.  # Label maps map indices to category names, so that when our convolution # network predicts `5`, we know that this corresponds to `king`.  # Here we use internal utility functions, but anything that returns a
# # dictionary mapping integers to appropriate string labels would be fine
# label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
# categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
# category_index = label_map_util.create_category_index(categories)
#
# # Load the Tensorflow model into memory.
# detection_graph = tf.Graph()
# with detection_graph.as_default():
#     od_graph_def = tf.GraphDef()
#     with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
#         serialized_graph = fid.read()
#         od_graph_def.ParseFromString(serialized_graph)
#         tf.import_graph_def(od_graph_def, name='')
#
#     sess = tf.Session(graph=detection_graph)
#
# # Define input and output tensors (i.e. data) for the object detection classifier
#
# # Input tensor is the image
# image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
#
# # Output tensors are the detection boxes, scores, and classes
# # Each box represents a part of the image where a particular object was detected
# detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
#
# # Each score represents level of confidence for each of the objects.
# # The score is shown on the result image, together with the class label.
# detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')
# detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')
#
# # Number of objects detected
# num_detections = detection_graph.get_tensor_by_name('num_detections:0')
#
# test_image_path = '/happy-walrus/models/version_3/images/test/'
# list_images = [file for file in os.listdir(test_image_path) if re.search('\.jpg', file)]
# for image_name in list_images:
#     # Load image using OpenCV and
#     # expand image dimensions to have shape: [1, None, None, 3]
#     # i.e. a single-column array, where each item in the column has the pixel RGB value
#     image = cv2.imread(test_image_path + image_name)
#     image_expanded = np.expand_dims(image, axis=0)
#     print(test_image_path + image_name)
#
#     # Perform the actual detection by running the model with the image as input
#     (boxes, scores, classes, num) = sess.run(
#         [detection_boxes, detection_scores, detection_classes, num_detections],
#         feed_dict={image_tensor: image_expanded})
#
#     # Draw the results of the detection (aka 'visulaize the results')
#     vis_util.visualize_boxes_and_labels_on_image_array(
#         image,
#         np.squeeze(boxes),
#         np.squeeze(classes).astype(np.int32),
#         np.squeeze(scores),
#         category_index,
#         use_normalized_coordinates=True,
#         line_thickness=8,
#         min_score_thresh=0.60)
#
#     cv2.imwrite('/happy-walrus/models/version_3/evaluation/' + MODEL_NAME + '/bboxes/' + image_name[:-4] + '_bbox.jpg', image)
#
# # All the results have been drawn on image. Now display the image.
# #print("Write successful to " + IMAGE[:-4] + '_pred.jpg')
# #cv2.imshow('Object detector', image)
#
# # Press any key to close the image
# # cv2.waitKey(0)
#
# # Clean up
# # cv2.destroyAllWindows()

# %% [markdown]
# Inference:
# - If `NoneType` related error, reinstall opencv with `apt install opencv-python`.
# - Change save path to model specific.

# %%
# !python {MAIN_PATH}Object_detection_image.py
# Out:
# WARNING:tensorflow:From /models/research/object_detection/utils/label_map_util.py:137: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /happy-walrus/models/version_3/Object_detection_image.py:62: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From /happy-walrus/models/version_3/Object_detection_image.py:68: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-11-30 21:15:14.490048: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2019-11-30 21:15:14.490105: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2019-11-30 21:15:14.490141: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (5df86dfc3c25): /proc/driver/nvidia/version does not exist
# 2019-11-30 21:15:14.490502: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-11-30 21:15:14.502005: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100060000 Hz
# 2019-11-30 21:15:14.502852: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x965c480 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2019-11-30 21:15:14.502888: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /happy-walrus/models/version_3/images/test/white_kitchen.EH.021.jpg
# 2019-11-30 21:15:20.740875: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 137779584 exceeds 10% of system memory.
# 2019-11-30 21:15:20.802642: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 138240000 exceeds 10% of system memory.
# 2019-11-30 21:15:20.947590: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 137779584 exceeds 10% of system memory.
# 2019-11-30 21:15:23.659605: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 2330496000 exceeds 10% of system memory.
# 2019-11-30 21:15:24.838563: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 2330496000 exceeds 10% of system memory.
# /happy-walrus/models/version_3/images/test/ADE_val_00000474.jpg
# /happy-walrus/models/version_3/images/test/ADE_val_00001482.jpg
# /happy-walrus/models/version_3/images/test/ADE_train_00010273.jpg
# /happy-walrus/models/version_3/images/test/kitchen_apartment.NM.075.jpg
# /happy-walrus/models/version_3/images/test/large_kitchen.EH.041.jpg
# /happy-walrus/models/version_3/images/test/ADE_train_00010631.jpg
# /happy-walrus/models/version_3/images/test/green_kitchen.NM.033.jpg
# /happy-walrus/models/version_3/images/test/small_kitchen.EH.048.jpg
# /happy-walrus/models/version_3/images/test/ADE_train_00010719.jpg
# /happy-walrus/models/version_3/images/test/small_kitchen.EH.068.jpg
# /happy-walrus/models/version_3/images/test/pintrest_messy_kitchen.EH.024.jpg
# /happy-walrus/models/version_3/images/test/ADE_train_00010493.jpg
# /happy-walrus/models/version_3/images/test/ADE_train_00010526.jpg
# /happy-walrus/models/version_3/images/test/big_kitchen.NM.032.jpg
# /happy-walrus/models/version_3/images/test/white_kitchen.EH.007.jpg
# /happy-walrus/models/version_3/images/test/tiny_kitchen.EH.016.jpg
# /happy-walrus/models/version_3/images/test/blue_kitchen.NM.033.jpg
# /happy-walrus/models/version_3/images/test/linoleum_kitchen.EH.042.jpg
# /happy-walrus/models/version_3/images/test/kitchen_appliances.NM.015.jpg
# /happy-walrus/models/version_3/images/test/green_kitchen.NM.007.jpg
# /happy-walrus/models/version_3/images/test/blue_kitchen.NM.036.jpg
# /happy-walrus/models/version_3/images/test/clean_kitchen.NM.015.jpg
# /happy-walrus/models/version_3/images/test/ADE_train_00010521.jpg
# /happy-walrus/models/version_3/images/test/ADE_train_00010260.jpg
# /happy-walrus/models/version_3/images/test/blue_kitchen.NM.025.jpg
# /happy-walrus/models/version_3/images/test/tiny_kitchen.EH.029.jpg
# /happy-walrus/models/version_3/images/test/white_kitchen.EH.011.jpg
# /happy-walrus/models/version_3/images/test/boiling_water.NM.009.jpg
# /happy-walrus/models/version_3/images/test/boiling_water.NM.020.jpg
# /happy-walrus/models/version_3/images/test/ADE_val_00000477.jpg
# /happy-walrus/models/version_3/images/test/ADE_train_00010178.jpg
# /happy-walrus/models/version_3/images/test/ADE_train_00000613.jpg
# /happy-walrus/models/version_3/images/test/European_kitchen.NM.031.jpg
# /happy-walrus/models/version_3/images/test/ADE_train_00010173.jpg
# /happy-walrus/models/version_3/images/test/red_kitchen.EH.028.jpg
# /happy-walrus/models/version_3/images/test/blue_kitchen.NM.085.jpg
# /happy-walrus/models/version_3/images/test/messy_kitchen.EH.025.jpg
# /happy-walrus/models/version_3/images/test/red_kitchen.EH.029.jpg
# /happy-walrus/models/version_3/images/test/blue_kitchen.NM.006.jpg
# /happy-walrus/models/version_3/images/test/Indian_kitchen.NM.003.jpg
# /happy-walrus/models/version_3/images/test/purple_kitchen.EH.005.jpg
# /happy-walrus/models/version_3/images/test/ADE_train_00010566.jpg
# /happy-walrus/models/version_3/images/test/kitchen_corners.NM.086.jpg
# /happy-walrus/models/version_3/images/test/green_kitchen.NM.018.jpg
# /happy-walrus/models/version_3/images/test/orange_kitchen.EH.043.jpg
# /happy-walrus/models/version_3/images/test/red_kitchen.EH.007.jpg
# /happy-walrus/models/version_3/images/test/kitchen_corners.NM.025.jpg
# /happy-walrus/models/version_3/images/test/kitchen_apartment.NM.085.jpg
# /happy-walrus/models/version_3/images/test/orange_kitchen.EH.069.jpg
# /happy-walrus/models/version_3/images/test/linoleum_kitchen.EH.030.jpg
# /happy-walrus/models/version_3/images/test/orange_kitchen.EH.070.jpg
# /happy-walrus/models/version_3/images/test/linoleum_kitchen.EH.022.jpg
# /happy-walrus/models/version_3/images/test/old_kitchen.EH.008.jpg
# /happy-walrus/models/version_3/images/test/pintrest_cluttered_kitchen.EH.076.jpg
# /happy-walrus/models/version_3/images/test/large_kitchen.EH.010.jpg
# /happy-walrus/models/version_3/images/test/ADE_val_00001472.jpg
# /happy-walrus/models/version_3/images/test/black_kitchen.NM.060.jpg
# /happy-walrus/models/version_3/images/test/large_kitchen.EH.038.jpg
# /happy-walrus/models/version_3/images/test/red_kitchen.EH.045.jpg
# /happy-walrus/models/version_3/images/test/ADE_train_00010411.jpg
# /happy-walrus/models/version_3/images/test/ADE_train_00010564.jpg
# /happy-walrus/models/version_3/images/test/black_kitchen.NM.007.jpg
# /happy-walrus/models/version_3/images/test/grey_kitchen.NM.071.jpg
# ^C

# %%
# !zip -rq {EVAL_PATH}/bboxes.zip {EVAL_PATH}

# %% [markdown]
# ### Evaluation metrics

# %% [markdown]
# Make inferences on test images

# %%
start = time.time()

# !python {OD_PATH}inference/infer_detections.py \
  --input_tfrecord_paths={MAIN_PATH}test.record \
  --output_tfrecord_path={EVAL_PATH}/test_detections.tfrecord-00000-of-00001 \
  --inference_graph={GRAPH_PATH}/frozen_inference_graph.pb \
  --discard_image_pixels

total_mins = (time.time() - start)
# !echo Seconds per image {total_mins / 284} > {EVAL_PATH}/inference_time.txt
# !cat {EVAL_PATH}/inference_time.txt
# Out:
# WARNING:tensorflow:From /models/research/object_detection/inference/infer_detections.py:96: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /models/research/object_detection/inference/infer_detections.py:57: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W1130 21:41:28.010958 139974755665728 module_wrapper.py:139] From /models/research/object_detection/inference/infer_detections.py:57: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /models/research/object_detection/inference/infer_detections.py:57: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W1130 21:41:28.011208 139974755665728 module_wrapper.py:139] From /models/research/object_detection/inference/infer_detections.py:57: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From /models/research/object_detection/inference/infer_detections.py:65: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W1130 21:41:28.011403 139974755665728 module_wrapper.py:139] From /models/research/object_detection/inference/infer_detections.py:65: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-11-30 21:41:28.012525: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2019-11-30 21:41:28.012579: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2019-11-30 21:41:28.012619: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (5df86dfc3c25): /proc/driver/nvidia/version does not exist
# 2019-11-30 21:41:28.012991: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-11-30 21:41:28.021234: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100060000 Hz
# 2019-11-30 21:41:28.021999: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x4fb8740 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2019-11-30 21:41:28.022037: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From /models/research/object_detection/inference/infer_detections.py:68: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W1130 21:41:28.024408 139974755665728 module_wrapper.py:139] From /models/research/object_detection/inference/infer_detections.py:68: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Reading input from 1 files
# I1130 21:41:28.024597 139974755665728 infer_detections.py:68] Reading input from 1 files
# WARNING:tensorflow:From /models/research/object_detection/inference/detection_inference.py:35: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W1130 21:41:28.025354 139974755665728 deprecation.py:323] From /models/research/object_detection/inference/detection_inference.py:35: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:277: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W1130 21:41:28.032891 139974755665728 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:277: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:189: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# W1130 21:41:28.033181 139974755665728 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:189: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:112: RefVariable.count_up_to (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Prefer Dataset.range instead.
# W1130 21:41:28.036712 139974755665728 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:112: RefVariable.count_up_to (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Prefer Dataset.range instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/variables.py:2522: count_up_to (from tensorflow.python.ops.state_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Prefer Dataset.range instead.
# W1130 21:41:28.036897 139974755665728 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/variables.py:2522: count_up_to (from tensorflow.python.ops.state_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Prefer Dataset.range instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:198: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W1130 21:41:28.040105 139974755665728 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:198: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:198: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W1130 21:41:28.041301 139974755665728 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:198: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /models/research/object_detection/inference/detection_inference.py:37: TFRecordReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.TFRecordDataset`.
# W1130 21:41:28.046020 139974755665728 deprecation.py:323] From /models/research/object_detection/inference/detection_inference.py:37: TFRecordReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.TFRecordDataset`.
# WARNING:tensorflow:From /models/research/object_detection/inference/detection_inference.py:39: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# W1130 21:41:28.047419 139974755665728 module_wrapper.py:139] From /models/research/object_detection/inference/detection_inference.py:39: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# WARNING:tensorflow:From /models/research/object_detection/inference/detection_inference.py:43: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# W1130 21:41:28.047626 139974755665728 module_wrapper.py:139] From /models/research/object_detection/inference/detection_inference.py:43: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# INFO:tensorflow:Reading graph and building model...
# I1130 21:41:28.104859 139974755665728 infer_detections.py:71] Reading graph and building model...
# WARNING:tensorflow:From /models/research/object_detection/inference/detection_inference.py:68: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# W1130 21:41:28.105243 139974755665728 module_wrapper.py:139] From /models/research/object_detection/inference/detection_inference.py:68: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /models/research/object_detection/inference/detection_inference.py:70: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# W1130 21:41:28.871236 139974755665728 module_wrapper.py:139] From /models/research/object_detection/inference/detection_inference.py:70: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From /models/research/object_detection/inference/detection_inference.py:76: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1130 21:41:31.897360 139974755665728 module_wrapper.py:139] From /models/research/object_detection/inference/detection_inference.py:76: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# INFO:tensorflow:Running inference and writing output to /happy-walrus/models/version_3/evaluation/autoaugm_nas/test_detections.tfrecord-00000-of-00001
# I1130 21:41:31.971276 139974755665728 infer_detections.py:77] Running inference and writing output to /happy-walrus/models/version_3/evaluation/autoaugm_nas/test_detections.tfrecord-00000-of-00001
# WARNING:tensorflow:From /models/research/object_detection/inference/infer_detections.py:78: The name tf.local_variables_initializer is deprecated. Please use tf.compat.v1.local_variables_initializer instead.
#
# W1130 21:41:31.971662 139974755665728 module_wrapper.py:139] From /models/research/object_detection/inference/infer_detections.py:78: The name tf.local_variables_initializer is deprecated. Please use tf.compat.v1.local_variables_initializer instead.
#
# WARNING:tensorflow:From /models/research/object_detection/inference/infer_detections.py:79: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W1130 21:41:32.310865 139974755665728 deprecation.py:323] From /models/research/object_detection/inference/infer_detections.py:79: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /models/research/object_detection/inference/infer_detections.py:80: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# W1130 21:41:32.312002 139974755665728 module_wrapper.py:139] From /models/research/object_detection/inference/infer_detections.py:80: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From /models/research/object_detection/inference/infer_detections.py:84: The name tf.logging.log_every_n is deprecated. Please use tf.compat.v1.logging.log_every_n instead.
#
# W1130 21:41:32.312448 139974755665728 module_wrapper.py:139] From /models/research/object_detection/inference/infer_detections.py:84: The name tf.logging.log_every_n is deprecated. Please use tf.compat.v1.logging.log_every_n instead.
#
# INFO:tensorflow:Processed 0 images...
# I1130 21:41:32.312628 139974755665728 infer_detections.py:85] Processed 0 images...
# WARNING:tensorflow:From /models/research/object_detection/inference/detection_inference.py:117: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W1130 21:41:32.312850 139974755665728 module_wrapper.py:139] From /models/research/object_detection/inference/detection_inference.py:117: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# 2019-11-30 21:41:41.198091: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 2330496000 exceeds 10% of system memory.
# 2019-11-30 21:41:41.747657: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 2330496000 exceeds 10% of system memory.
# 2019-11-30 21:41:42.566554: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 1306368000 exceeds 10% of system memory.
# 2019-11-30 21:42:05.202109: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 2330496000 exceeds 10% of system memory.
# 2019-11-30 21:42:05.563422: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 2330496000 exceeds 10% of system memory.
# INFO:tensorflow:Processed 10 images...
# I1130 21:45:32.052571 139974755665728 infer_detections.py:85] Processed 10 images...
# INFO:tensorflow:Processed 20 images...
# I1130 21:49:26.148298 139974755665728 infer_detections.py:85] Processed 20 images...
# INFO:tensorflow:Processed 30 images...
# I1130 21:53:19.091527 139974755665728 infer_detections.py:85] Processed 30 images...
# INFO:tensorflow:Processed 40 images...
# I1130 21:57:11.479052 139974755665728 infer_detections.py:85] Processed 40 images...
# INFO:tensorflow:Processed 50 images...
# I1130 22:01:06.522840 139974755665728 infer_detections.py:85] Processed 50 images...
# INFO:tensorflow:Processed 60 images...
# I1130 22:05:01.332063 139974755665728 infer_detections.py:85] Processed 60 images...
# INFO:tensorflow:Processed 70 images...
# I1130 22:08:54.601628 139974755665728 infer_detections.py:85] Processed 70 images...
# INFO:tensorflow:Processed 80 images...
# I1130 22:12:48.216490 139974755665728 infer_detections.py:85] Processed 80 images...
# INFO:tensorflow:Processed 90 images...
# I1130 22:16:44.743881 139974755665728 infer_detections.py:85] Processed 90 images...
# INFO:tensorflow:Processed 100 images...
# I1130 22:20:38.813850 139974755665728 infer_detections.py:85] Processed 100 images...
# INFO:tensorflow:Processed 110 images...
# I1130 22:24:33.062038 139974755665728 infer_detections.py:85] Processed 110 images...
# INFO:tensorflow:Processed 120 images...
# I1130 22:28:27.152596 139974755665728 infer_detections.py:85] Processed 120 images...
# INFO:tensorflow:Processed 130 images...
# I1130 22:32:22.325907 139974755665728 infer_detections.py:85] Processed 130 images...
# INFO:tensorflow:Processed 140 images...
# I1130 22:36:16.369371 139974755665728 infer_detections.py:85] Processed 140 images...
# INFO:tensorflow:Processed 150 images...
# I1130 22:40:11.018658 139974755665728 infer_detections.py:85] Processed 150 images...
# INFO:tensorflow:Processed 160 images...
# I1130 22:44:06.052399 139974755665728 infer_detections.py:85] Processed 160 images...
# INFO:tensorflow:Processed 170 images...
# I1130 22:48:00.918812 139974755665728 infer_detections.py:85] Processed 170 images...
# INFO:tensorflow:Processed 180 images...
# I1130 22:51:54.921949 139974755665728 infer_detections.py:85] Processed 180 images...
# INFO:tensorflow:Processed 190 images...
# I1130 22:55:50.089904 139974755665728 infer_detections.py:85] Processed 190 images...
# INFO:tensorflow:Processed 200 images...
# I1130 22:59:45.428858 139974755665728 infer_detections.py:85] Processed 200 images...
# INFO:tensorflow:Processed 210 images...
# I1130 23:03:42.452481 139974755665728 infer_detections.py:85] Processed 210 images...
# INFO:tensorflow:Processed 220 images...
# I1130 23:07:35.593994 139974755665728 infer_detections.py:85] Processed 220 images...
# INFO:tensorflow:Processed 230 images...
# I1130 23:11:27.304659 139974755665728 infer_detections.py:85] Processed 230 images...
# INFO:tensorflow:Processed 240 images...
# I1130 23:15:20.439119 139974755665728 infer_detections.py:85] Processed 240 images...
# INFO:tensorflow:Processed 250 images...
# I1130 23:19:14.819193 139974755665728 infer_detections.py:85] Processed 250 images...
# INFO:tensorflow:Processed 260 images...
# I1130 23:23:07.500003 139974755665728 infer_detections.py:85] Processed 260 images...
# INFO:tensorflow:Processed 270 images...
# I1130 23:27:00.386108 139974755665728 infer_detections.py:85] Processed 270 images...
# INFO:tensorflow:Processed 280 images...
# I1130 23:30:53.167972 139974755665728 infer_detections.py:85] Processed 280 images...
# INFO:tensorflow:Finished processing records
# I1130 23:32:03.135974 139974755665728 infer_detections.py:92] Finished processing records
# Seconds per image 23.37534101916031

# %% [markdown]
# Calculate performance metrics.
# - There are two documented bugs, solved implementing [this solution](https://github.com/tensorflow/models/issues/3252#issuecomment-363669586) and [this one](https://github.com/tensorflow/models/issues/5924#issuecomment-455081147).
#     - Replace line 162 in `metrics/offline_eval_map_corloc.py` for `input_config = configs['eval_input_configs'][0]`.
#     - Replace lines 47 to 49 in `metrics/tf_example_parser.py` with:
#         ```python
#             if tf_example.features.feature[self.field_name].HasField("bytes_list"):
#                 result = tf_example.features.feature[self.field_name].bytes_list.value
#                 result = "".join([x if type(x)=='str' else x.decode('utf-8') for x in result])
#             else:
#                 result = None
#             return result
#         ```
#
# - Update MODEL_NAME.

# %%
MODEL_NAME
# Out:
# 'autoaugm_nas'

# %%
# %%bash
# OD_PATH='/models/research/object_detection/'
# MAIN_PATH='/happy-walrus/models/version_3/'
# IMG_PATH=${MAIN_PATH}images/
# MODEL_NAME=autoaugm_nas/
# TRAIN_PATH=${MAIN_PATH}training/${MODEL_NAME}
# EVAL_PATH=${MAIN_PATH}evaluation/${MODEL_NAME}
# GRAPH_PATH=${MAIN_PATH}inference_graph${MODEL_NAME}
# METRICS_PATH=${EVAL_PATH}eval_metrics/
# # Choose metrics set from:
# #   - coco_detection_metrics (multiple IoUs)
# #   - pascal_voc_detection_metrics (per-class)
# METRICS_SET='pascal_voc_detection_metrics'
#
# mkdir -p ${METRICS_PATH}
#
# echo "
# label_map_path: '/happy-walrus/models/version_3/training/labelmap.pbtxt'
# tf_record_input_reader: { input_path: '${EVAL_PATH}test_detections.tfrecord-00000-of-00001' }
# " > ${METRICS_PATH}test_input_config.pbtxt
#
# echo "
# metrics_set: 'pascal_voc_detection_metrics'
# " > ${METRICS_PATH}test_eval_pascal_config.pbtxt
#
# echo "
# metrics_set: 'coco_detection_metrics'
# " > ${METRICS_PATH}test_eval_coco_config.pbtxt
#
# python ${OD_PATH}metrics/offline_eval_map_corloc.py \
#   --eval_dir=${METRICS_PATH} \
#   --eval_config_path=${METRICS_PATH}test_eval_pascal_config.pbtxt \
#   --input_config_path=${METRICS_PATH}test_input_config.pbtxt
#
# mv ${METRICS_PATH}metrics.csv ${METRICS_PATH}metrics_pascal.csv
#
# python ${OD_PATH}metrics/offline_eval_map_corloc.py \
#   --eval_dir=${METRICS_PATH} \
#   --eval_config_path=${METRICS_PATH}test_eval_coco_config.pbtxt \
#   --input_config_path=${METRICS_PATH}test_input_config.pbtxt
#
# mv ${METRICS_PATH}metrics.csv ${METRICS_PATH}metrics_coco.csv
# Out:
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.76s).
# Accumulating evaluation results...
# DONE (t=0.43s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.425
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.639
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.477
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.425
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.589
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.601
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.601
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /models/research/object_detection/metrics/offline_eval_map_corloc.py:46: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /models/research/object_detection/metrics/offline_eval_map_corloc.py:46: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From /models/research/object_detection/metrics/offline_eval_map_corloc.py:172: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /models/research/object_detection/utils/config_util.py:236: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W1130 23:39:41.054167 140235150952256 module_wrapper.py:139] From /models/research/object_detection/utils/config_util.py:236: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /models/research/object_detection/metrics/offline_eval_map_corloc.py:105: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W1130 23:39:41.057017 140235150952256 module_wrapper.py:139] From /models/research/object_detection/metrics/offline_eval_map_corloc.py:105: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Processing file: /happy-walrus/models/version_3/evaluation/autoaugm_nas/test_detections.tfrecord-00000-of-00001
# I1130 23:39:41.057162 140235150952256 offline_eval_map_corloc.py:105] Processing file: /happy-walrus/models/version_3/evaluation/autoaugm_nas/test_detections.tfrecord-00000-of-00001
# WARNING:tensorflow:From /models/research/object_detection/metrics/offline_eval_map_corloc.py:107: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# W1130 23:39:41.057347 140235150952256 deprecation.py:323] From /models/research/object_detection/metrics/offline_eval_map_corloc.py:107: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /models/research/object_detection/metrics/offline_eval_map_corloc.py:111: The name tf.logging.log_every_n is deprecated. Please use tf.compat.v1.logging.log_every_n instead.
#
# W1130 23:39:41.068604 140235150952256 module_wrapper.py:139] From /models/research/object_detection/metrics/offline_eval_map_corloc.py:111: The name tf.logging.log_every_n is deprecated. Please use tf.compat.v1.logging.log_every_n instead.
#
# INFO:tensorflow:Processed 0 images...
# I1130 23:39:41.068848 140235150952256 offline_eval_map_corloc.py:112] Processed 0 images...
# I1130 23:39:42.802622 140235150952256 object_detection_evaluation.py:1311] average_precision: 0.340141
# I1130 23:39:42.818060 140235150952256 object_detection_evaluation.py:1311] average_precision: 0.781298
# I1130 23:39:42.841192 140235150952256 object_detection_evaluation.py:1311] average_precision: 0.591367
# I1130 23:39:42.846161 140235150952256 object_detection_evaluation.py:1311] average_precision: 0.638554
# I1130 23:39:42.856064 140235150952256 object_detection_evaluation.py:1311] average_precision: 0.489999
# I1130 23:39:42.861027 140235150952256 object_detection_evaluation.py:1311] average_precision: 0.850707
# I1130 23:39:42.863074 140235150952256 object_detection_evaluation.py:1311] average_precision: 0.329622
# I1130 23:39:42.866983 140235150952256 object_detection_evaluation.py:1311] average_precision: 0.805955
# I1130 23:39:42.876465 140235150952256 object_detection_evaluation.py:1311] average_precision: 0.836989
# I1130 23:39:42.886282 140235150952256 object_detection_evaluation.py:1311] average_precision: 0.740210
# INFO:tensorflow:Writing metrics.
# I1130 23:39:42.889142 140235150952256 offline_eval_map_corloc.py:142] Writing metrics.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /models/research/object_detection/metrics/offline_eval_map_corloc.py:46: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /models/research/object_detection/metrics/offline_eval_map_corloc.py:46: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From /models/research/object_detection/metrics/offline_eval_map_corloc.py:172: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /models/research/object_detection/utils/config_util.py:236: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W1130 23:39:46.825313 140207764412224 module_wrapper.py:139] From /models/research/object_detection/utils/config_util.py:236: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /models/research/object_detection/metrics/offline_eval_map_corloc.py:105: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W1130 23:39:46.827886 140207764412224 module_wrapper.py:139] From /models/research/object_detection/metrics/offline_eval_map_corloc.py:105: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Processing file: /happy-walrus/models/version_3/evaluation/autoaugm_nas/test_detections.tfrecord-00000-of-00001
# I1130 23:39:46.828022 140207764412224 offline_eval_map_corloc.py:105] Processing file: /happy-walrus/models/version_3/evaluation/autoaugm_nas/test_detections.tfrecord-00000-of-00001
# WARNING:tensorflow:From /models/research/object_detection/metrics/offline_eval_map_corloc.py:107: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# W1130 23:39:46.828212 140207764412224 deprecation.py:323] From /models/research/object_detection/metrics/offline_eval_map_corloc.py:107: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /models/research/object_detection/metrics/offline_eval_map_corloc.py:111: The name tf.logging.log_every_n is deprecated. Please use tf.compat.v1.logging.log_every_n instead.
#
# W1130 23:39:46.839601 140207764412224 module_wrapper.py:139] From /models/research/object_detection/metrics/offline_eval_map_corloc.py:111: The name tf.logging.log_every_n is deprecated. Please use tf.compat.v1.logging.log_every_n instead.
#
# INFO:tensorflow:Processed 0 images...
# I1130 23:39:46.839813 140207764412224 offline_eval_map_corloc.py:112] Processed 0 images...
# INFO:tensorflow:Performing evaluation on 283 images.
# I1130 23:39:47.221077 140207764412224 coco_evaluation.py:205] Performing evaluation on 283 images.
# INFO:tensorflow:Loading and preparing annotation results...
# I1130 23:39:47.223085 140207764412224 coco_tools.py:115] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.02s)
# I1130 23:39:47.241180 140207764412224 coco_tools.py:137] DONE (t=0.02s)
# INFO:tensorflow:Writing metrics.
# I1130 23:39:50.492889 140207764412224 offline_eval_map_corloc.py:142] Writing metrics.

# %%
# coco_detection_metrics
# !csvtool readable {EVAL_PATH}/eval_metrics/metrics_coco.csv
# Out:
# DetectionBoxes_Precision/mAP          0.4254768658556712
# DetectionBoxes_Precision/mAP@.50IOU   0.6393673247203288
# DetectionBoxes_Precision/mAP@.75IOU   0.4769207938127609
# DetectionBoxes_Precision/mAP (small)  0.4254768658556712
# DetectionBoxes_Precision/mAP (medium) -1.0
# DetectionBoxes_Precision/mAP (large)  -1.0
# DetectionBoxes_Recall/AR@1            0.37732274793094106
# DetectionBoxes_Recall/AR@10           0.5891368446412659
# DetectionBoxes_Recall/AR@100          0.6006276293417087
# DetectionBoxes_Recall/AR@100 (small)  0.6006276293417087
# DetectionBoxes_Recall/AR@100 (medium) -1.0
# DetectionBoxes_Recall/AR@100 (large)  -1.0

# %%
# pascal_voc_detection_metrics
# !csvtool readable {EVAL_PATH}/eval_metrics/metrics_pascal.csv
# Out:
# PascalBoxes_Precision/mAP@0.5IOU                       0.640484228888385
# PascalBoxes_PerformanceByCategory/AP@0.5IOU/cabinet    0.34014091346677877
# PascalBoxes_PerformanceByCategory/AP@0.5IOU/chair      0.7812978292653084
# PascalBoxes_PerformanceByCategory/AP@0.5IOU/countertop 0.5913671526730557
# PascalBoxes_PerformanceByCategory/AP@0.5IOU/dishwasher 0.6385543857657348
# PascalBoxes_PerformanceByCategory/AP@0.5IOU/outlet     0.4899992791750931
# PascalBoxes_PerformanceByCategory/AP@0.5IOU/oven       0.8507067183876558
# PascalBoxes_PerformanceByCategory/AP@0.5IOU/sofa       0.32962184873949574
# PascalBoxes_PerformanceByCategory/AP@0.5IOU/stool      0.8059549306967608
# PascalBoxes_PerformanceByCategory/AP@0.5IOU/stove      0.8369890023185909
# PascalBoxes_PerformanceByCategory/AP@0.5IOU/utensil    0.740210228395376

# %% [markdown]
# # References

# %% [markdown]
# - [State of the Art Object Detection - Medium](https://medium.com/@lessw/state-of-the-art-object-detection-use-these-top-3-data-augmentations-and-google-brains-optimal-57ac6d8d1de5)
# - [Learning Data Augmentation Strategies for Object Detection](https://arxiv.org/abs/1906.11172v1)
